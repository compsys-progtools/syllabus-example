# %% [markdown]
# # Format and Schedule
#
# ## Structure
#
# This class is cerntered on active learning.  Over the course of the semester, we will cover topics through multiple lenses so that you get multiple chances to build skill with the tools that we are learning and see how the important concepts repeat in different ways throughout
#
# There will prescribed preparation work for each class session that either helps you preview tricky topics in advance or refresh your memory of prerequisite material so that you are ready to learn the new material.
#
# In class we will focus on answering a new question together each session through a combination of inquiry-driven participatory live coding and discussions. You will be expected to follow along with the activity and answer questions to check understanding.
#
# After each class there will 2 sets of activities based on that material, you can choose which level to work at.  The review level activities require you to review what was done in class and ensure that you understand it.  The practice level tasks give you a chance to get more practice and apply your understanding in new ways beyond what we do in class.
#
#
#
#
# ## Topics
#
# This is the planned schedule, but is subject to change in order to adapt to how things go in class or additional questions that come up.
#
# Each class we will answer a motivating question in a way that integrates important practical skills, conceptual knowledge, and social context of computer systems and programming tools.
#
# We will focus on *learning* the tools to start, treating them as an example of how computer systems are designed and then *using* the tools to study the system in the second half of the semester.

# %%
import pandas as pd
pd.read_csv('schedule.csv',index_col='date')
# Out:
#                                                      question  \
# date
# 2023-09-07                   Welcome, Introduction, and Setup
# 2023-09-12                      Course Logistics and Learning
# 2023-09-14                           Bash intro & git offline
# 2023-09-19              How can I work with branches offline?
# 2023-09-21      When do I get an advantage from git and bash?
# 2023-09-26                                What *is* a commit?
# 2023-09-28         How do programmers communicate about code?
# 2023-10-03                                     What *is* git?
# 2023-10-05                     Why are these tools like this?
# 2023-10-12                        How does git make a commit?
# 2023-10-17           How can can I release and share my code?
# 2023-10-19                           What is a commit number?
# 2023-10-24               How can I automate things with bash?
# 2023-10-26                 How can I work on a remote server?
# 2023-10-31                                    What is an IDE?
# 2023-11-02  How do I choose a Programming Language for a p...
# 2023-11-07  How can I authenitcate more securely from a te...
# 2023-11-09                   What Happens when we build code?
# 2023-11-14                     What happens when we run code?
# 2023-11-16  How does a computer represent non integer quan...
# 2023-11-21                 How can we use logical operations?
# 2023-11-28                              What *is* a computer?
# 2023-11-30                How does timing work in a computer?
# 2023-12-05   How do different types of storage work together?
# 2023-12-07                    How does this all work together
# 2023-12-12                          How did this semester go?
#
#                           keyword  \
# date
# 2023-09-07                  intro
# 2023-09-12              logistics
# 2023-09-14         terminal start
# 2023-09-19             gitoffline
# 2023-09-21           why terminal
# 2023-09-26        merge conflicts
# 2023-09-28          documentation
# 2023-10-03          git structure
# 2023-10-05        unix philosophy
# 2023-10-12          git internals
# 2023-10-17         git references
# 2023-10-19                numbers
# 2023-10-24         bash scripting
# 2023-10-26                 server
# 2023-10-31                    IDE
# 2023-11-02  programming languages
# 2023-11-07             server use
# 2023-11-09               building
# 2023-11-14                hardwar
# 2023-11-16                 floats
# 2023-11-21      bitwise operation
# 2023-11-28           architecture
# 2023-11-30                 timing
# 2023-12-05                 memory
# 2023-12-07                 review
# 2023-12-12               feedback
#
#                                                    conceptual  \
# date
# 2023-09-07                  what is a system, why study tools
# 2023-09-12                            github flow with issues
# 2023-09-14               git structure, paths and file system
# 2023-09-19                                       git branches
# 2023-09-21   computing mental model, paths and file structure
# 2023-09-26                               versions, git vlaues
# 2023-09-28   build, automation, modularity, pattern matching,
# 2023-10-03  what is a file system, how does git keep track...
# 2023-10-05              unix philosophy, debugging strategies
# 2023-10-12  pointers, design and abstraction, intermediate...
# 2023-10-17                    pointers, git branches and tags
# 2023-10-19                             hashes, number systems
# 2023-10-24  bash is a programming language, official docs,...
# 2023-10-26                           server, hpc, large files
# 2023-10-31                                          IDE parts
# 2023-11-02                  types of PLs, what is PL studying
# 2023-11-07                     ssh keys, hpc system strucutre
# 2023-11-09                                    building C code
# 2023-11-14                            von neuman architecture
# 2023-11-16                               float representation
# 2023-11-21  what is a bit, what is a register, how to brea...
# 2023-11-28                            physical gates, history
# 2023-11-30                    timing, control unit, threading
# 2023-12-05   different type of memory, different abstractions
# 2023-12-07                                                all
# 2023-12-12                                                all
#
#                                                     practical  \
# date
# 2023-09-07                                      GitHub basics
# 2023-09-12                                           syllabus
# 2023-09-14  bash path navigation, git terminal authentication
# 2023-09-19     github flow offline, resolving merge conflicts
# 2023-09-21                    bash navigation, tab completion
# 2023-09-26  merge conflicts in github, merge conflicts wit...
# 2023-09-28  generate documentation with jupyterbook, gitig...
# 2023-10-03  find in bash, seeing git config, plumbing/porc...
# 2023-10-05                       decision making for branches
# 2023-10-12  inspecting git objects, when hashes are unique...
# 2023-10-17  git branches, advanced fixing, semver and conv...
# 2023-10-19        git commit numbers, manual hashing with git
# 2023-10-24  script files, man pages, bash variables, bash ...
# 2023-10-26             ssh, large files, bash head, grep, etc
# 2023-10-31                          compare and contrast IDEs
# 2023-11-02                  choosing a language for a project
# 2023-11-07                       ssh keys, interactive, slurm
# 2023-11-09                             ssh keys, gcc compiler
# 2023-11-14                  reading a basic assembly language
# 2023-11-16                     floats do not equal themselves
# 2023-11-21                                   how an ALU works
# 2023-11-28                                interpretting specs
# 2023-11-30             threaded program with a race condition
# 2023-12-05                            working with large data
# 2023-12-07                          end of semester logistics
# 2023-12-12                                            grading
#
#                                                        social  \
# date
# 2023-09-07                                       class intros
# 2023-09-12         working together and building common vocab
# 2023-09-14  why developers work differently than casual users
# 2023-09-19  commuication is important, git can help fix mi...
# 2023-09-21  collaboration requires shared language, shared...
# 2023-09-26  human and machine readable, commit messages ar...
# 2023-09-28            main vs master, documentation community
# 2023-10-03  git workflows are conventions, git can be used...
# 2023-10-05  social advantages of shared mental model, diff...
# 2023-10-12                        conventions vs requirements
# 2023-10-17  advantages of data that is both human and mach...
# 2023-10-19             number  systems are derived in culture
# 2023-10-24      using automation to make collaboration easier
# 2023-10-26               hidden impacts of remote computation
# 2023-10-31      collaboration features, developer communities
# 2023-11-02              usability depends on prior experience
# 2023-11-07           social aspects of passwords and security
# 2023-11-09  file extensions are for people, when vocabular...
# 2023-11-14        historical context of computer architecures
# 2023-11-16  social processes around standard developents, ...
# 2023-11-21  tech interviews look for obscure details somet...
# 2023-11-28               social context influences technology
# 2023-11-30          different times matter in different cases
# 2023-12-05                           privacy/respect for data
# 2023-12-07                                   group work final
# 2023-12-12                       how to learn better together
#
#                                                      activity
# date
# 2023-09-07  create kwl repo in github, navigate github.com...
# 2023-09-12   set up to work offline together, create a folder
# 2023-09-14            navigate files and clone a repo locally
# 2023-09-19             clone a repo and make a branch locally
# 2023-09-21  work with bash and recover from a mistake with...
# 2023-09-26  examine commit objects, introduce plumbing com...
# 2023-09-28                                 make a jupyterbook
# 2023-10-03  examine git from multiple definitions and insp...
# 2023-10-05                discussion with minor code examples
# 2023-10-12            create a commit using plumbing commands
# 2023-10-17                             make a tag and release
# 2023-10-19               discussion and use hashing algorithm
# 2023-10-24        build a bash script that calculates a grade
# 2023-10-26  log into a remote server and work with large f...
# 2023-10-31                   discussions and sharing IDE tips
# 2023-11-02                 discussion or independent research
# 2023-11-07                configure and use ssh keys on a hpc
# 2023-11-09   build code in C and examine intermediate outputs
# 2023-11-14  use a hardware simulator to see step by step o...
# 2023-11-16  work with float representation through fractio...
# 2023-11-21        derive addition from basic logic operations
# 2023-11-28                                         discussion
# 2023-11-30  write a threaded program and fix a race condition
# 2023-12-05          large data that has to be read in batches
# 2023-12-07      review quiz, integration/reflection questions
# 2023-12-12                                         discussion

# %% [markdown]
# ##  Lab schedule
#
# Lab provides extra support and accountability.  Some lab activities will directly be time to work on tasks from review or practice badges.  Some lab activities will help you review class material. Some lab activities will include self-assessments and reflection on your course progress to ensure that you are not falling behind.
#
# Every week at the end of lab you will "check out" with a TA or instructor, reviewing your work and showing that you completed any setup or install steps that are needed for the upcoming classes. The checkout is evaluated only on completion, any components that are important to get correct will be assessed in a review or practice badge.

# %%
pd.read_csv('labschedule.csv',index_col='date')
# Out:
#                               topic  \
# date
# 2023-10-06          unix philosophy
# 2023-09-22         offline branches
# 2023-10-13             git plumbing
# 2023-10-27                scripting
# 2023-09-08            GitHub Basics
# 2023-12-08                       os
# 2023-09-29         tool familiarity
# 2023-11-03              remote, hpc
# 2023-11-17   Machine representation
# 2023-11-10                Compiling
# 2023-10-20             git plumbing
# 2023-09-15  working at the terminal
# 2023-12-01                 hardware
#
#                                                      activity
# date
# 2023-10-06  design a command line tool that would enable a...
# 2023-09-22               plan for success, clean a messy repo
# 2023-10-13                            git plumbing experiment
# 2023-10-27                             releases and packaging
# 2023-09-08                               syllabus quiz, setup
# 2023-12-08                                hardware simulation
# 2023-09-29               work on badges, self progress report
# 2023-11-03                         server work, batch scripts
# 2023-11-17               bits and floats and number libraries
# 2023-11-10                            C compiling experiments
# 2023-10-20          grade calculation script, self reflection
# 2023-09-15     organization, setup kwl locally, manage issues
# 2023-12-01       self-reflection, work, project consultations
